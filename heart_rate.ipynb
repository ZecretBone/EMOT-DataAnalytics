# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
self_annotation_multimodal = pd.read_excel('datasets/ECG_GSR_Emotions/Self-Annotation Labels/Self-annotation Multimodal_Use.xlsx')
self_annotation_multimodal['annotation'] = 'M'
self_annotation_multimodal.rename(columns = {'V_Label':'Valence', 'A_Label':'Arousal', 'Four_Labels':'Four_Label'}, inplace = True)
self_annotation_multimodal
# Out:
#      Participant Id  Session ID  Video ID Name  Age  Gender  Valence level  \
# 0                 1           1         1  M_M   13  Female              8
# 1                 1           1         2  M_M   13  Female              4
# 2                 1           1         2  M_M   13  Female              4
# 3                 1           1         4  M_M   13  Female              9
# 4                 1           1         5  M_M   13  Female              0
# ..              ...         ...       ...  ...  ...     ...            ...
# 247              12           3         3  Q_M   11    Male              4
# 248              12           3         4  Q_M   11    Male              4
# 249              12           3         5  Q_M   11    Male              4
# 250              12           3         6  Q_M   11    Male              2
# 251              12           3         7  Q_M   11    Male              2
#
#      Arousal level  Dominance level     Happy  ...     Anger   Neutral  \
# 0                0                0      High  ...   VeryLow   VeryLow
# 1                0                0   VeryLow  ...   VeryLow   VeryLow
# 2                0                0   VeryLow  ...   VeryLow   VeryLow
# 3                0                0  VeryHigh  ...   VeryLow   VeryLow
# 4                9                0   VeryLow  ...   VeryLow   VeryLow
# ..             ...              ...       ...  ...       ...       ...
# 247              9                0   VeryLow  ...   VeryLow   VeryLow
# 248              0                0      High  ...   VeryLow  Moderate
# 249              0                0  Moderate  ...       Low   VeryLow
# 250              7                2   VeryLow  ...  VeryHigh       Low
# 251              3                3   VeryLow  ...       Low       Low
#
#       Disgust Surprised Familiarity Score   Emotion Valence Arousal  \
# 0     VeryLow   VeryLow     Never watched     Happy      HV      LA
# 1     VeryLow   VeryLow               NaN       Sad      LV      LA
# 2     VeryLow       Low               NaN  Surprise      LV      LA
# 3     VeryLow   VeryLow               NaN     Happy      HV      LA
# 4    VeryHigh   VeryLow               NaN   Disgust      LV      HA
# ..        ...       ...               ...       ...     ...     ...
# 247   VeryLow   VeryLow     Never watched     Mixed      LV      HA
# 248   VeryLow  Moderate     Never watched     Happy      LV      LA
# 249   VeryLow  Moderate     Never watched     Mixed      LV      LA
# 250   VeryLow       Low     Never watched     Anger      LV      HA
# 251   VeryLow  Moderate     Never watched      Fear      LV      LA
#
#     Four_Label annotation
# 0         HVLA          M
# 1         LVLA          M
# 2         LVLA          M
# 3         HVLA          M
# 4         LVHA          M
# ..         ...        ...
# 247       LVHA          M
# 248       LVLA          M
# 249       LVLA          M
# 250       LVHA          M
# 251       LVLA          M
#
# [252 rows x 22 columns]

# %%
dummies1 = pd.get_dummies(self_annotation_multimodal.Gender)
 
# Concatenate the dummies to original dataframe
merged1 = pd.concat([self_annotation_multimodal.iloc[:, :5], dummies1, self_annotation_multimodal.iloc[:, 6:]], axis='columns')
merged1
# Out:
#      Participant Id  Session ID  Video ID Name  Age  Female  Male  \
# 0                 1           1         1  M_M   13       1     0
# 1                 1           1         2  M_M   13       1     0
# 2                 1           1         2  M_M   13       1     0
# 3                 1           1         4  M_M   13       1     0
# 4                 1           1         5  M_M   13       1     0
# ..              ...         ...       ...  ...  ...     ...   ...
# 247              12           3         3  Q_M   11       0     1
# 248              12           3         4  Q_M   11       0     1
# 249              12           3         5  Q_M   11       0     1
# 250              12           3         6  Q_M   11       0     1
# 251              12           3         7  Q_M   11       0     1
#
#      Valence level  Arousal level  Dominance level  ...     Anger   Neutral  \
# 0                8              0                0  ...   VeryLow   VeryLow
# 1                4              0                0  ...   VeryLow   VeryLow
# 2                4              0                0  ...   VeryLow   VeryLow
# 3                9              0                0  ...   VeryLow   VeryLow
# 4                0              9                0  ...   VeryLow   VeryLow
# ..             ...            ...              ...  ...       ...       ...
# 247              4              9                0  ...   VeryLow   VeryLow
# 248              4              0                0  ...   VeryLow  Moderate
# 249              4              0                0  ...       Low   VeryLow
# 250              2              7                2  ...  VeryHigh       Low
# 251              2              3                3  ...       Low       Low
#
#       Disgust Surprised Familiarity Score   Emotion Valence Arousal  \
# 0     VeryLow   VeryLow     Never watched     Happy      HV      LA
# 1     VeryLow   VeryLow               NaN       Sad      LV      LA
# 2     VeryLow       Low               NaN  Surprise      LV      LA
# 3     VeryLow   VeryLow               NaN     Happy      HV      LA
# 4    VeryHigh   VeryLow               NaN   Disgust      LV      HA
# ..        ...       ...               ...       ...     ...     ...
# 247   VeryLow   VeryLow     Never watched     Mixed      LV      HA
# 248   VeryLow  Moderate     Never watched     Happy      LV      LA
# 249   VeryLow  Moderate     Never watched     Mixed      LV      LA
# 250   VeryLow       Low     Never watched     Anger      LV      HA
# 251   VeryLow  Moderate     Never watched      Fear      LV      LA
#
#     Four_Label annotation
# 0         HVLA          M
# 1         LVLA          M
# 2         LVLA          M
# 3         HVLA          M
# 4         LVHA          M
# ..         ...        ...
# 247       LVHA          M
# 248       LVLA          M
# 249       LVLA          M
# 250       LVHA          M
# 251       LVLA          M
#
# [252 rows x 23 columns]

# %%
self_annotation_singlemodal = pd.read_excel('datasets/ECG_GSR_Emotions/Self-Annotation Labels/Self-annotation Single Modal_Use.xlsx')
self_annotation_multimodal['annotation'] = 'S'
self_annotation_singlemodal
# Out:
#      Participant Id  Session Id  Video Id  Name  Age    Male  Valence level  \
# 0                 1           1         1   M_W   21  Female              6
# 1                 1           1         2   M_W   21  Female              2
# 2                 1           1         3   M_W   21  Female              7
# 3                 1           1         4   M_W   21  Female              7
# 4                 1           1         5   M_W   21  Female              0
# ..              ...         ...       ...   ...  ...     ...            ...
# 149              12           1         3  Ah_D   14    Male              9
# 150              12           1         4  Ah_D   14    Male              4
# 151              12           1         5  Ah_D   14    Male              0
# 152              12           1         6  Ah_D   14    Male              0
# 153              12           1         7  Ah_D   14    Male              0
#
#     Arousal level  Dominance level     Happy  ...      Fear     Anger  \
# 0               0                0  Moderate  ...   VeryLow   VeryLow
# 1               4                2   VeryLow  ...       Low  VeryHigh
# 2               6                6  Moderate  ...   VeryLow       Low
# 3               3                4  Moderate  ...   VeryLow   VeryLow
# 4               8                8   VeryLow  ...   VeryLow      High
# ..            ...              ...       ...  ...       ...       ...
# 149             0                9  VeryHigh  ...       Low   VeryLow
# 150             7                0  VeryHigh  ...      High  Moderate
# 151             9                0   VeryLow  ...   VeryLow      High
# 152             9                0   VeryLow  ...   VeryLow  VeryHigh
# 153             0                0   VeryLow  ...  VeryHigh   VeryLow
#
#       Neutral   Disgust Surprised Familiarity Score  Emotion Valence Arousal  \
# 0    VeryHigh   VeryLow   VeryLow                 5  Neutral      HV      LA
# 1     VeryLow  Moderate  Moderate     Never watched    Anger      LV      LA
# 2    Moderate   VeryLow  Moderate     Never watched    Mixed      HV      HA
# 3         Low   VeryLow       Low     Never watched    Mixed      HV      LA
# 4     VeryLow  VeryHigh      High     Never watched  Disgust      LV      HA
# ..        ...       ...       ...               ...      ...     ...     ...
# 149   VeryLow   VeryLow   VeryLow     Never watched    Happy      HV      LA
# 150   VeryLow   VeryLow   VeryLow     Never watched    Happy      LV      HA
# 151   VeryLow  VeryHigh   VeryLow     Never watched  Disgust      LV      HA
# 152   VeryLow   VeryLow   VeryLow     Never watched    Anger      LV      HA
# 153   VeryLow   VeryLow   VeryLow     Never watched     Fear      LV      LA
#
#     Four_Label
# 0         HVLA
# 1         LVLA
# 2         HVHA
# 3         HVLA
# 4         LVHA
# ..         ...
# 149       HVLA
# 150       LVHA
# 151       LVHA
# 152       LVHA
# 153       LVLA
#
# [154 rows x 21 columns]

# %%
dummies2 = pd.get_dummies(self_annotation_singlemodal.Male)
 
# Concatenate the dummies to original dataframe
merged2 = pd.concat([self_annotation_singlemodal.iloc[:, :5], dummies2, self_annotation_singlemodal.iloc[:, 6:]], axis='columns')
merged2
# Out:
#      Participant Id  Session Id  Video Id  Name  Age  Female  Male  \
# 0                 1           1         1   M_W   21       1     0
# 1                 1           1         2   M_W   21       1     0
# 2                 1           1         3   M_W   21       1     0
# 3                 1           1         4   M_W   21       1     0
# 4                 1           1         5   M_W   21       1     0
# ..              ...         ...       ...   ...  ...     ...   ...
# 149              12           1         3  Ah_D   14       0     1
# 150              12           1         4  Ah_D   14       0     1
# 151              12           1         5  Ah_D   14       0     1
# 152              12           1         6  Ah_D   14       0     1
# 153              12           1         7  Ah_D   14       0     1
#
#      Valence level Arousal level  Dominance level  ...      Fear     Anger  \
# 0                6             0                0  ...   VeryLow   VeryLow
# 1                2             4                2  ...       Low  VeryHigh
# 2                7             6                6  ...   VeryLow       Low
# 3                7             3                4  ...   VeryLow   VeryLow
# 4                0             8                8  ...   VeryLow      High
# ..             ...           ...              ...  ...       ...       ...
# 149              9             0                9  ...       Low   VeryLow
# 150              4             7                0  ...      High  Moderate
# 151              0             9                0  ...   VeryLow      High
# 152              0             9                0  ...   VeryLow  VeryHigh
# 153              0             0                0  ...  VeryHigh   VeryLow
#
#       Neutral   Disgust Surprised Familiarity Score  Emotion Valence Arousal  \
# 0    VeryHigh   VeryLow   VeryLow                 5  Neutral      HV      LA
# 1     VeryLow  Moderate  Moderate     Never watched    Anger      LV      LA
# 2    Moderate   VeryLow  Moderate     Never watched    Mixed      HV      HA
# 3         Low   VeryLow       Low     Never watched    Mixed      HV      LA
# 4     VeryLow  VeryHigh      High     Never watched  Disgust      LV      HA
# ..        ...       ...       ...               ...      ...     ...     ...
# 149   VeryLow   VeryLow   VeryLow     Never watched    Happy      HV      LA
# 150   VeryLow   VeryLow   VeryLow     Never watched    Happy      LV      HA
# 151   VeryLow  VeryHigh   VeryLow     Never watched  Disgust      LV      HA
# 152   VeryLow   VeryLow   VeryLow     Never watched    Anger      LV      HA
# 153   VeryLow   VeryLow   VeryLow     Never watched     Fear      LV      LA
#
#     Four_Label
# 0         HVLA
# 1         LVLA
# 2         HVHA
# 3         HVLA
# 4         LVHA
# ..         ...
# 149       HVLA
# 150       LVHA
# 151       LVHA
# 152       LVHA
# 153       LVLA
#
# [154 rows x 22 columns]

# %%
self_annotation_frames = [merged1, merged2]
merged_dataframe = pd.concat(self_annotation_frames)
merged_dataframe
# Out:
#      Participant Id  Session ID  Video ID  Name  Age  Female  Male  \
# 0                 1         1.0       1.0   M_M   13       1     0
# 1                 1         1.0       2.0   M_M   13       1     0
# 2                 1         1.0       2.0   M_M   13       1     0
# 3                 1         1.0       4.0   M_M   13       1     0
# 4                 1         1.0       5.0   M_M   13       1     0
# ..              ...         ...       ...   ...  ...     ...   ...
# 149              12         NaN       NaN  Ah_D   14       0     1
# 150              12         NaN       NaN  Ah_D   14       0     1
# 151              12         NaN       NaN  Ah_D   14       0     1
# 152              12         NaN       NaN  Ah_D   14       0     1
# 153              12         NaN       NaN  Ah_D   14       0     1
#
#      Valence level Arousal level  Dominance level  ...   Disgust Surprised  \
# 0                8             0                0  ...   VeryLow   VeryLow
# 1                4             0                0  ...   VeryLow   VeryLow
# 2                4             0                0  ...   VeryLow       Low
# 3                9             0                0  ...   VeryLow   VeryLow
# 4                0             9                0  ...  VeryHigh   VeryLow
# ..             ...           ...              ...  ...       ...       ...
# 149              9             0                9  ...   VeryLow   VeryLow
# 150              4             7                0  ...   VeryLow   VeryLow
# 151              0             9                0  ...  VeryHigh   VeryLow
# 152              0             9                0  ...   VeryLow   VeryLow
# 153              0             0                0  ...   VeryLow   VeryLow
#
#     Familiarity Score   Emotion Valence Arousal Four_Label annotation  \
# 0       Never watched     Happy      HV      LA       HVLA          M
# 1                 NaN       Sad      LV      LA       LVLA          M
# 2                 NaN  Surprise      LV      LA       LVLA          M
# 3                 NaN     Happy      HV      LA       HVLA          M
# 4                 NaN   Disgust      LV      HA       LVHA          M
# ..                ...       ...     ...     ...        ...        ...
# 149     Never watched     Happy      HV      LA       HVLA        NaN
# 150     Never watched     Happy      LV      HA       LVHA        NaN
# 151     Never watched   Disgust      LV      HA       LVHA        NaN
# 152     Never watched     Anger      LV      HA       LVHA        NaN
# 153     Never watched      Fear      LV      LA       LVLA        NaN
#
#     Session Id Video Id
# 0          NaN      NaN
# 1          NaN      NaN
# 2          NaN      NaN
# 3          NaN      NaN
# 4          NaN      NaN
# ..         ...      ...
# 149        1.0      3.0
# 150        1.0      4.0
# 151        1.0      5.0
# 152        1.0      6.0
# 153        1.0      7.0
#
# [406 rows x 25 columns]

# %%
train_d_frame = merged_dataframe.copy().drop(['Video ID', 'Happy', 'Sad', 'Fear',
                                        'Anger', 'Neutral', 'Disgust', 'Surprised', 'Four_Label', 'annotation'
                                       ], axis = 1)
# train_d_frame.drop(colummns=[c for c in train_d_frame.columns if 'Unnamed' in c], )
for x in train_d_frame.columns:
    if 'Unnamed' in x:
        train_d_frame.drop(columns=x, inplace=True)

train_d_frame
# Out:
#      Participant Id  Session ID  Name  Age  Female  Male  Valence level  \
# 0                 1         1.0   M_M   13       1     0              8
# 1                 1         1.0   M_M   13       1     0              4
# 2                 1         1.0   M_M   13       1     0              4
# 3                 1         1.0   M_M   13       1     0              9
# 4                 1         1.0   M_M   13       1     0              0
# ..              ...         ...   ...  ...     ...   ...            ...
# 149              12         NaN  Ah_D   14       0     1              9
# 150              12         NaN  Ah_D   14       0     1              4
# 151              12         NaN  Ah_D   14       0     1              0
# 152              12         NaN  Ah_D   14       0     1              0
# 153              12         NaN  Ah_D   14       0     1              0
#
#     Arousal level  Dominance level Familiarity Score   Emotion Valence  \
# 0               0                0     Never watched     Happy      HV
# 1               0                0               NaN       Sad      LV
# 2               0                0               NaN  Surprise      LV
# 3               0                0               NaN     Happy      HV
# 4               9                0               NaN   Disgust      LV
# ..            ...              ...               ...       ...     ...
# 149             0                9     Never watched     Happy      HV
# 150             7                0     Never watched     Happy      LV
# 151             9                0     Never watched   Disgust      LV
# 152             9                0     Never watched     Anger      LV
# 153             0                0     Never watched      Fear      LV
#
#     Arousal  Session Id  Video Id
# 0        LA         NaN       NaN
# 1        LA         NaN       NaN
# 2        LA         NaN       NaN
# 3        LA         NaN       NaN
# 4        HA         NaN       NaN
# ..      ...         ...       ...
# 149      LA         1.0       3.0
# 150      HA         1.0       4.0
# 151      HA         1.0       5.0
# 152      HA         1.0       6.0
# 153      LA         1.0       7.0
#
# [406 rows x 15 columns]

# %% [markdown]
# **training**

# %%
features = ['Age', 'Female', 'Male', 'Arousal level', 'Arousal']
cl = { 'LA':0, 'HA':1}
train_d_frame['Arousal'] = train_d_frame['Arousal'].map(cl)
X = train_d_frame[features]
y = train_d_frame.iloc[:, 10]

# %%
# tr = train_d_frame[['Arousal level', 'Valence level']]
# train_d_frame['Arousal level'] = train_d_frame['Arousal level'].astype(str).astype('int64')
# df_num = tr.select_dtypes(exclude=[int])
# df_num
#tr.loc[:, tr.dtypes == object]
train_d_frame
# Out:
# Empty DataFrame
# Columns: [Participant Id, Session ID, Name, Age, Female, Male, Valence level, Arousal level, Dominance level, Familiarity Score, Emotion, Valence, Arousal, Session Id, Video Id]
# Index: []

# %%
train_d_frame.dtypes
# Out:
# Participant Id         int64
# Session ID           float64
# Name                  object
# Age                    int64
# Female                 uint8
# Male                   uint8
# Valence level          int64
# Arousal level         object
# Dominance level        int64
# Familiarity Score     object
# Emotion               object
# Valence               object
# Arousal                int64
# Session Id           float64
# Video Id             float64
# dtype: object

# %%
#Preparing the model
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.20, random_state = 99)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[168], line 3
#       1 #Preparing the model
#       2 from sklearn.model_selection import train_test_split, GridSearchCV, KFold
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.20, random_state = 99)
#
# File c:\ProgramData\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2562, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2559 arrays = indexable(*arrays)
#    2561 n_samples = _num_samples(arrays[0])
# -> 2562 n_train, n_test = _validate_shuffle_split(
#    2563     n_samples, test_size, train_size, default_test_size=0.25
#    2564 )
#    2566 if shuffle is False:
#    2567     if stratify is not None:
#
# File c:\ProgramData\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2236, in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2233 n_train, n_test = int(n_train), int(n_test)
#    2235 if n_train == 0:
# -> 2236     raise ValueError(
#    2237         "With n_samples={}, test_size={} and train_size={}, the "
#    2238         "resulting train set will be empty. Adjust any of the "
#    2239         "aforementioned parameters.".format(n_samples, test_size, train_size)
#    2240     )
#    2242 return n_train, n_test
#
# ValueError: With n_samples=0, test_size=0.2 and train_size=None, the resulting train set will be empty. Adjust any of the aforementioned parameters.

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()

cv = KFold(n_splits=10, random_state=1, shuffle=True)

grid_params_knn = { 'n_neighbors' : range(1,20)}

gs = GridSearchCV(KNeighborsClassifier(), grid_params_knn, cv=cv)
gs.fit(X_train, y_train)
gs.best_params_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[86], line 9
#       6 grid_params_knn = { 'n_neighbors' : range(1,20)}
#       8 gs = GridSearchCV(KNeighborsClassifier(), grid_params_knn, cv=cv)
# ----> 9 gs.fit(X_train, y_train)
#      10 gs.best_params_
#
# File c:\ProgramData\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File c:\ProgramData\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\ProgramData\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:851, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     844 elif len(out) != n_candidates * n_splits:
#     845     raise ValueError(
#     846         "cv.split and cv.get_n_splits returned "
#     847         "inconsistent results. Expected {} "
#     848         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     849     )
# --> 851 _warn_or_raise_about_fit_failures(out, self.error_score)
#     853 # For callable self.scoring, the return type is only know after
#     854 # calling. If the return type is a dictionary, the error scores
#     855 # can now be inserted with the correct key. The type checking
#     856 # of out will be done in `_insert_error_scores`.
#     857 if callable(self.scoring):
#
# File c:\ProgramData\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:367, in _warn_or_raise_about_fit_failures(results, error_score)
#     360 if num_failed_fits == num_fits:
#     361     all_fits_failed_message = (
#     362         f"\nAll the {num_fits} fits failed.\n"
#     363         "It is very likely that your model is misconfigured.\n"
#     364         "You can try to debug the error by setting error_score='raise'.\n\n"
#     365         f"Below are more details about the failures:\n{fit_errors_summary}"
#     366     )
# --> 367     raise ValueError(all_fits_failed_message)
#     369 else:
#     370     some_fits_failed_message = (
#     371         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     372         "The score on these train-test partitions for these parameters"
#    (...)
#     376         f"Below are more details about the failures:\n{fit_errors_summary}"
#     377     )
#
# ValueError:
# All the 190 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 190 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\ProgramData\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\ProgramData\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py", line 215, in fit
#     return self._fit(X, y)
#   File "c:\ProgramData\anaconda3\lib\site-packages\sklearn\neighbors\_base.py", line 454, in _fit
#     X, y = self._validate_data(
#   File "c:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py", line 565, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "c:\ProgramData\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 1106, in check_X_y
#     X = check_array(
#   File "c:\ProgramData\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 879, in check_array
#     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#   File "c:\ProgramData\anaconda3\lib\site-packages\sklearn\utils\_array_api.py", line 185, in _asarray_with_order
#     array = numpy.asarray(array, order=order, dtype=dtype)
#   File "c:\ProgramData\anaconda3\lib\site-packages\pandas\core\generic.py", line 2070, in __array__
#     return np.asarray(self._values, dtype=dtype)
# ValueError: could not convert string to float: '⁸'
